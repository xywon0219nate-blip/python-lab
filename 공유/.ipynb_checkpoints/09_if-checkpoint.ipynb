# %% [markdown]
# # if문
# - 지정한 조건에 따라 다르게 분기해 명령을 수행
# - 조건의 만족 여부에 따라서 코드 수행 결과가 달라짐
# - 단일  조건에  따른 분기 (if )

# %% [markdown]
# ![image.png](attachment:da855fec-142b-47ee-92e4-08a046951ab1.png)

# %% [markdown]
# ----
# ⭐ 구문 ⭐
# - 코드블럭은 들여쓰기로만 구분
# - 보통은 한줄에 한 문장, 길어지면 '\'로 연결
# - 한줄에 여러 문장을 쓸 때 는 ';' 로구분
# - 주석은 '#'으로 시작
# ----

# %% [markdown]
# ## 비교 연산자
#
# | 비교 연산자 | 의미        | 활용 예   | 설명                    |
# |-------------|-------------|-----------|-------------------------|
# | ==          | 같다        | a == b    | a는 b와 같다            |
# | !=          | 같지 않다   | a != b    | a는  b와  같지 않다     |
# | &lt;        | 작다        | a &lt; b  | a는  b보다 작다         |
# | &gt;        | 크다        | a &gt; b  | a는  b보다 크다         |
# | &lt;=       | 작거나 같다 | a &lt;= b | a는  b보다  작거나 같다 |
# | &gt;=       | 크거나 같다 | a &gt;= b | a는  b보다  크거나 같다 |

# %% [markdown]
# ----
# ## 논리 연산자
# | 논리 연산자 | 의미     | 활용 예 | 설명                                                            |   |
# |-------------|----------|---------|-----------------------------------------------------------------|---|
# | and         | 논리곱   | A and B | A와  B가  모두  참이면  참이고    그  외에는  거짓              |   |
# | or          | 논리합   | A or B  | A와  B  중  하나라도  참이면    참이고  둘  다  거짓이면   거짓 |   |
# | not         | 논리부정 | not A   | A가  참이면  거짓이고    거짓이면  참                           |   |

# %% [markdown]
# ## 1. if

# %% [markdown]
# ![image.png](attachment:7b3f1508-ead2-4147-a02e-d87d8f252385.png)

# %% [markdown]
# <br>
#
# ## 2. if~else
# <조건문>의 만족 여부에 따라 코드를 다르게 수행하려면 'if ~ else' 구조의 조건문을 이용

# %% [markdown]
# ![image.png](attachment:ee307ede-aeaf-4b05-8d78-06c5c4fb1613.png)

# %% [markdown]
# ## 3. if ~ elif ~ else
# 여러 조건에 따른 분기

# %% [markdown]
# ![image.png](attachment:98cf6850-ac3b-49d4-aac3-20be73e900ab.png)

# %% [markdown]
# <br>
#
# ## 4. 중첩 if

# %% [markdown]
# ![image.png](attachment:0d0a3431-2b2f-4c5e-91c5-0108033fcdab.png)
