# %% [markdown]
# # 컨테이너 타입이란?
#
# * 컨테이너 타입은 여러 개의 값을 다루는 자료형입니다. **list, tuple, set, dictionary**가 있습니다.
#     - **리스트(list)** : 데이터를 연속적으로 관리, 값을 바꿀 수 있음, 예:`['가', '나', '다', '라']`
#
#     - **튜플(tuple)** : 데이터를 연속적으로 관리, 값을 바꿀 수 없음, 예:`('가', '나', '다', '라')`
#     - **세트(set)** : 집합과 같은 속성, 예:`{'가', '나', '다', '라'}`
#     - **딕셔너리(dictionary)** : key-value 쌍, 예: `{'가':123, '나':456, '다':789}`

# %% [markdown]
# # List(리스트)
#
# - 여러 개의 데이터를 묶어서 처리할 때 사용

# %% [markdown]
# ![image.png](attachment:45df34ef-bfc1-4bdd-b9dd-886011d9e300.png)

# %% [markdown]
# ## 1. List 생성
# - 대괄호[] 사용, 라인의 데이터는 콤마(,)로 구분
# - [] 입력 시 반 리스트로 생성
# - List의 데이터는 다양하게 저장 가능

# %% [markdown]
# ## 3. List 연산

# %% [markdown]
# - 더하기(+)
# - 곱하기(*)
# - 범위 지정(

# %% [markdown]
# ### (4).remove
# - 항목 삭제하기 : remove(아이템)

# %% [markdown]
# ### (5).pop
# - 마지막 아이템 삭제

# %% [markdown]
# ### 6.index
# - 아이템 현재 인덱스 확인 : index(아이템)
# -

# %% [markdown]
# ### 7.count
