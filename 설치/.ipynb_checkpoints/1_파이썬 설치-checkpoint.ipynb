# %% [markdown]
# # Python 설치

# %% [markdown]
# ## 1. 다운로드
#
# - 다운로드 사이트 : https://www.python.org/
#
# ![image.png](attachment:3d146d6e-9bc2-4ec0-a81b-12c24a164ebf.png)

# %% [markdown]
# ## 2. 다운로드
#
# - 운영체제에 맞는 설치파일 다운로드 하기
#
# ![image.png](attachment:78f99ae6-3c32-49f2-b22e-5c7b79ab5cc3.png)

# %% [markdown]
# ## 3. 설치
#
# - PATH 추가 체크
#
# ![image.png](attachment:20e5805c-0d04-48a6-ba74-5a9493bf7c83.png)

# %% [markdown]
# ## 4. 설치 진행
#
# ![image.png](attachment:b342c939-53f6-44d4-ac7a-4c1bc980f76a.png)

# %% [markdown]
# ## 5. 설치 완료
#
# ![image.png](attachment:d6580478-2fa8-4edb-b40d-8501630df6a2.png)

# %% [markdown]
# ## 6. 버전 확인
#
# ![image.png](attachment:52e05d2c-63ac-4575-ae41-49f170dc418f.png)
