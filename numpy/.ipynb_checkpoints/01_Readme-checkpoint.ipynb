# %% [markdown]
# # NumPy

# %% [markdown]
# ### 학습 목표
#
# - ndarray의 개념과 차원, shape 개념을 이해한다.
# - 목적에 맞는 인덱싱 방법을 선택할 수 있다.
# - 집계함수를 활용하여 여러 배열을 그룹핑할 수 있다.
# - argsort() 함수를 활용하여 배열을 정렬한다.
# - axis 개념을 잘 이해하고 활용한다.
