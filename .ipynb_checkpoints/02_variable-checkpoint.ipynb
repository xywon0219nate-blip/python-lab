# %% [markdown]
# # 1. 변수

# %% [markdown]
# - 자료(데이터)를 넣을 수 있는 저장 공간
# - 변수명 : 변수를 넣는 공간에 붙인 이름
# - 형식 : 변수명 = 자료(데이터)

# %%
# a라는 변수에 10을 입력
a = 10
print(a)
# Out:
# 10

# %%
b = 3
print(a+b)
b = 100
print(a+b)
# Out:
# 13
# 110

# %%
print(a)
print(b)
print(a*b)
# Out:
# 10
# 100
# 1000

# %%
str1 = "홍길동"
str2 = '청길동'
print(str1)
print(str2)
# Out:
# 홍길동
# 청길동

# %%
radio_freq=107.7
radio_freq
# Out:
# 107.7

# %% [markdown]
# boolean_flag = True
# boolean_flag

# %% [markdown]
# # 2. 변수 이름을 붙이는 규칙(1)
# ## ⭐️ 반드시 지켜야 할 규칙
# - 숫자로 시작하지 않는다
# - 공백이 포함되지 않는다
# - 기호가 포함되지 않는다
# - 예약어 (키워드)는 사용하지 않는다

# %%
happy_python = "파이썬" # camelCase, snakecase 타입은 가능

# %%
# 3. 변수 이름을 붙이는 규칙(2)
## ⭐️ 에러 발생은 안되지만, 참고사항

- 대소문자 구분
- 한 번에 여러 개의 변수 선언 가능
- 하나의 값을 여러 변수에 저장 가능
